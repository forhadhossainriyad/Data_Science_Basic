# %%
import pandas as pd

# %%
df = pd.read_csv("Horror Movies.csv")

# %%
df.head()
# Out:
#    Movie Title  Movie Year  Runtime                      Genre  Rating  \
# 0        Alien        1979      117             Horror, Sci-Fi     8.5
# 1       Psycho        1960      109  Horror, Mystery, Thriller     8.5
# 2  The Shining        1980      146              Drama, Horror     8.4
# 3    The Thing        1982      109    Horror, Mystery, Sci-Fi     8.2
# 4      Tumbbad        2018      104     Drama, Fantasy, Horror     8.2
#
#            Director      Votes    Gross
# 0      Ridley Scott   9,05,275  $78.90M
# 1  Alfred Hitchcock   6,89,068  $32.00M
# 2   Stanley Kubrick  10,51,582  $44.02M
# 3    John Carpenter   4,39,793  $13.78M
# 4   Rahi Anil Barve     53,297      NaN

# %%
df.shape
# Out:
# (836, 8)

# %%
rows, cols = df.shape

# %%
rows
# Out:
# 836

# %%
cols
# Out:
# 8

# %%
#print the value of df
df.values
# Out:
# array([['Alien', 1979, 117, ..., 'Ridley Scott', '9,05,275', '$78.90M'],
#        ['Psycho', 1960, 109, ..., 'Alfred Hitchcock', '6,89,068',
#         '$32.00M'],
#        ['The Shining', 1980, 146, ..., 'Stanley Kubrick', '10,51,582',
#         '$44.02M'],
#        ...,
#        ['Alone in the Dark', 2005, 96, ..., 'Uwe Boll', '46,403',
#         '$5.18M'],
#        ['House of the Dead', 2003, 90, ..., 'Uwe Boll', '38,041',
#         '$10.25M'],
#        ['Manos: The Hands of Fate', 1966, 70, ..., 'Harold P. Warren',
#         '37,060', nan]], dtype=object)

# %%
df.columns
# Out:
# Index(['Movie Title', 'Movie Year', 'Runtime', 'Genre', 'Rating', 'Director',
#        'Votes', 'Gross'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=836, step=1)

# %%
df.head(3)
# Out:
#    Movie Title  Movie Year  Runtime                      Genre  Rating  \
# 0        Alien        1979      117             Horror, Sci-Fi     8.5
# 1       Psycho        1960      109  Horror, Mystery, Thriller     8.5
# 2  The Shining        1980      146              Drama, Horror     8.4
#
#            Director      Votes    Gross
# 0      Ridley Scott   9,05,275  $78.90M
# 1  Alfred Hitchcock   6,89,068  $32.00M
# 2   Stanley Kubrick  10,51,582  $44.02M

# %%
df.Runtime
# Out:
# 0      117
# 1      109
# 2      146
# 3      109
# 4      104
#       ...
# 831     95
# 832    141
# 833     96
# 834     90
# 835     70
# Name: Runtime, Length: 836, dtype: int64

# %%
df['Movie Title']
# Out:
# 0                         Alien
# 1                        Psycho
# 2                   The Shining
# 3                     The Thing
# 4                       Tumbbad
#                  ...
# 831                     Troll 2
# 832                      Laxmii
# 833           Alone in the Dark
# 834           House of the Dead
# 835    Manos: The Hands of Fate
# Name: Movie Title, Length: 836, dtype: object

# %%
df[['Movie Title']]
# Out:
#                   Movie Title
# 0                       Alien
# 1                      Psycho
# 2                 The Shining
# 3                   The Thing
# 4                     Tumbbad
# ..                        ...
# 831                   Troll 2
# 832                    Laxmii
# 833         Alone in the Dark
# 834         House of the Dead
# 835  Manos: The Hands of Fate
#
# [836 rows x 1 columns]

# %%
df['Movie Title'].head(20)
# Out:
# 0                                Alien
# 1                               Psycho
# 2                          The Shining
# 3                            The Thing
# 4                              Tumbbad
# 5                         The Exorcist
# 6                           Diabolique
# 7                      Rosemary's Baby
# 8     What Ever Happened to Baby Jane?
# 9          The Cabinet of Dr. Caligari
# 10                   The Blue Elephant
# 11                   Shaun of the Dead
# 12                           Nosferatu
# 13                Let the Right One In
# 14                           King Kong
# 15                           Get Out I
# 16                            Predator
# 17                     I Saw the Devil
# 18                    Dawn of the Dead
# 19            Night of the Living Dead
# Name: Movie Title, dtype: object

# %%
df[['Movie Title','Movie Year']].head(20)
# Out:
#                          Movie Title  Movie Year
# 0                              Alien        1979
# 1                             Psycho        1960
# 2                        The Shining        1980
# 3                          The Thing        1982
# 4                            Tumbbad        2018
# 5                       The Exorcist        1973
# 6                         Diabolique        1955
# 7                    Rosemary's Baby        1968
# 8   What Ever Happened to Baby Jane?        1962
# 9        The Cabinet of Dr. Caligari        1920
# 10                 The Blue Elephant        2014
# 11                 Shaun of the Dead        2004
# 12                         Nosferatu        1922
# 13              Let the Right One In        2008
# 14                         King Kong        1933
# 15                         Get Out I        2017
# 16                          Predator        1987
# 17                   I Saw the Devil        2010
# ...

# %%
df.Runtime.sort_values()
# Out:
# 297     57
# 20      64
# 9       67
# 835     70
# 21      70
#       ...
# 64     156
# 74     159
# 289    169
# 10     170
# 51     191
# Name: Runtime, Length: 836, dtype: int64

# %%
df['Movie Title'].sort_values()
# Out:
# 391                    #Alive
# 102       10 Cloverfield Lane
# 409                   13 Sins
# 199                      1408
# 427                      1922
#                 ...
# 31                 Zombieland
# 220    Zombieland: Double Tap
# 761          [REC] 3: Genesis
# 326                    [Rec]²
# 204                  eXistenZ
# Name: Movie Title, Length: 836, dtype: object

# %%
df['Movie Year'].sort_values()
# Out:
# 9      1920
# 12     1922
# 21     1931
# 70     1931
# 20     1932
#        ...
# 461    2023
# 460    2023
# 328    2023
# 465    2023
# 215    2023
# Name: Movie Year, Length: 836, dtype: int64

# %%
df['Movie Year'].sort_values(ascending=False)
# Out:
# 215    2023
# 465    2023
# 328    2023
# 460    2023
# 461    2023
#        ...
# 20     1932
# 70     1931
# 21     1931
# 12     1922
# 9      1920
# Name: Movie Year, Length: 836, dtype: int64

# %%
df.sort_values('Movie Title', ascending=False)
# Out:
#                 Movie Title  Movie Year  Runtime                     Genre  \
# 204                eXistenZ        1999       97   Horror, Mystery, Sci-Fi
# 326                  [Rec]²        2009       85          Horror, Thriller
# 761        [REC] 3: Genesis        2012       80          Horror, Thriller
# 220  Zombieland: Double Tap        2019       99    Action, Comedy, Horror
# 31               Zombieland        2009       88    Action, Comedy, Horror
# ..                      ...         ...      ...                       ...
# 427                    1922        2017      102      Crime, Drama, Horror
# 199                    1408        2007      104  Fantasy, Horror, Mystery
# 409                 13 Sins        2014       93          Horror, Thriller
# 102     10 Cloverfield Lane        2016      103    Drama, Horror, Mystery
# 391                  #Alive        2020       98     Action, Drama, Horror
#
#      Rating          Director     Votes    Gross
# ...

# %%
df.describe()
# Out:
#         Movie Year     Runtime      Rating
# count   836.000000  836.000000  836.000000
# mean   2004.271531  100.767943    6.160167
# std      16.330837   14.484556    0.940355
# min    1920.000000   57.000000    1.600000
# 25%    1998.000000   91.000000    5.600000
# 50%    2009.000000   98.000000    6.200000
# 75%    2016.000000  108.000000    6.800000
# max    2023.000000  191.000000    8.500000

# %%
df
# Out:
#                   Movie Title  Movie Year  Runtime                      Genre  \
# 0                       Alien        1979      117             Horror, Sci-Fi
# 1                      Psycho        1960      109  Horror, Mystery, Thriller
# 2                 The Shining        1980      146              Drama, Horror
# 3                   The Thing        1982      109    Horror, Mystery, Sci-Fi
# 4                     Tumbbad        2018      104     Drama, Fantasy, Horror
# ..                        ...         ...      ...                        ...
# 831                   Troll 2        1990       95    Comedy, Fantasy, Horror
# 832                    Laxmii        2020      141     Action, Comedy, Horror
# 833         Alone in the Dark        2005       96     Action, Horror, Sci-Fi
# 834         House of the Dead        2003       90  Action, Adventure, Horror
# 835  Manos: The Hands of Fate        1966       70                     Horror
#
# ...

# %%
df[df['Rating']>7]
# Out:
#                       Movie Title  Movie Year  Runtime  \
# 0                           Alien        1979      117
# 1                          Psycho        1960      109
# 2                     The Shining        1980      146
# 3                       The Thing        1982      109
# 4                         Tumbbad        2018      104
# ..                            ...         ...      ...
# 136                    Timecrimes        2007       92
# 137               Black Christmas        1974       98
# 138         A Tale of Two Sisters        2003      114
# 139                        Thirst        2009      134
# 140  The Fearless Vampire Killers        1967       91
#
#                          Genre  Rating          Director      Votes    Gross
# 0               Horror, Sci-Fi     8.5      Ridley Scott   9,05,275  $78.90M
# 1    Horror, Mystery, Thriller     8.5  Alfred Hitchcock   6,89,068  $32.00M
# ...

# %%
df[df['Rating']<5]
# Out:
#                   Movie Title  Movie Year  Runtime                      Genre  \
# 763             Knock Knock I        2015       99       Crime, Drama, Horror
# 764          The Darkest Hour        2011       89  Action, Adventure, Horror
# 765            Fantasy Island        2020      109   Fantasy, Horror, Mystery
# 766              Dracula 2000        2000       99    Action, Fantasy, Horror
# 767   Silent Hill: Revelation        2012       95  Horror, Mystery, Thriller
# ..                        ...         ...      ...                        ...
# 831                   Troll 2        1990       95    Comedy, Fantasy, Horror
# 832                    Laxmii        2020      141     Action, Comedy, Horror
# 833         Alone in the Dark        2005       96     Action, Horror, Sci-Fi
# 834         House of the Dead        2003       90  Action, Adventure, Horror
# 835  Manos: The Hands of Fate        1966       70                     Horror
#
# ...

# %%
#subseting numerial value
df[df['Movie Title'].isin(['Alien','The Darkest Hour'])]
# Out:
#           Movie Title  Movie Year  Runtime                      Genre  Rating  \
# 0               Alien        1979      117             Horror, Sci-Fi     8.5
# 764  The Darkest Hour        2011       89  Action, Adventure, Horror     4.9
#
#          Director     Votes    Gross
# 0    Ridley Scott  9,05,275  $78.90M
# 764   Chris Gorak    62,428  $21.43M
